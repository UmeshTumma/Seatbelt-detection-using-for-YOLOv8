# %%
# !pip install ultralytics

# %% [markdown]
# Image Demo

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r"C:\Umesh college\Project file\Seatbelt_Detection\Predict Result\Seatbelt_Detection\weights\best.pt")  # Pretrained YOLO model

# Run batched inference on a list of images
results = model([r"C:\Umesh college\Project file\Seatbelt_Detection\Demo Image SD\istockphoto-1331415031-612x612.jpg"])  # Returns a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Bounding box outputs
    masks = result.masks  # Segmentation masks outputs
    keypoints = result.keypoints  # Pose outputs
    probs = result.probs  # Classification outputs
    obb = result.obb  # Oriented boxes outputs
    result.show()  # Display to screen
    result.save(filename="result.jpg")  # Save to disk
# Out:
# 0: 448x640 1 seatbelt, 633.5ms
# Speed: 12.2ms preprocess, 633.5ms inference, 10.8ms postprocess per image at shape (1, 3, 448, 640)

# %% [markdown]
# Video Demo

# %%
from ultralytics import YOLO
import cv2

# Load YOLO model
model = YOLO(r"C:\Umesh college\Project file\Seatbelt_Detection\Predict Result\Seatbelt_Detection\weights\best.pt")

# Open video file
video_path = r"C:\Umesh college\Project file\Seatbelt_Detection\Demo Image SD\test_Trim.mp4"
cap = cv2.VideoCapture(video_path)

# Check if video is opened
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Get FPS for smooth display
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Process video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO inference and get processed frame
    frame = model(frame)[0].plot()

    # Display output
    cv2.imshow("YOLOv8 Helmet Detection", frame)

    # Adjust delay for smooth visualization
    if cv2.waitKey(int(1000 / fps)) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 seatbelts, 521.2ms
# Speed: 3.7ms preprocess, 521.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 seatbelts, 630.4ms
# Speed: 5.7ms preprocess, 630.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 seatbelts, 626.6ms
# Speed: 5.2ms preprocess, 626.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 seatbelts, 566.5ms
# Speed: 5.2ms preprocess, 566.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 seatbelts, 480.4ms
# Speed: 3.2ms preprocess, 480.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 seatbelts, 467.7ms
# Speed: 2.0ms preprocess, 467.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 seatbelts, 490.6ms
# Speed: 2.7ms preprocess, 490.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 seatbelts, 500.3ms
# ...

# %% [markdown]
# Live Demo

# %%
import cv2
from ultralytics import YOLO

model = YOLO(r"Seatbelt_Detection/Seatbelt_Detection/weights/best.pt")
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    exit("Error: Could not open webcam.")

while True:
    success, frame = cap.read()
    if not success:
        break

    results = model(frame)
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"{model.names[int(box.cls[0])]}: {box.conf[0]:.2f}", 
                        (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    cv2.imshow("Helmet Detection", frame)
    if cv2.waitKey(1) == ord("z"):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 770.9ms
# Speed: 6.0ms preprocess, 770.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 790.4ms
# Speed: 2.6ms preprocess, 790.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 725.5ms
# Speed: 2.0ms preprocess, 725.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 707.8ms
# Speed: 1.9ms preprocess, 707.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 701.2ms
# Speed: 2.4ms preprocess, 701.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 698.9ms
# Speed: 2.9ms preprocess, 698.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 789.5ms
# Speed: 3.8ms preprocess, 789.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

model = YOLO(r'C:\Umesh college\Project file\Seatbelt_Detection\Seatbelt_Detection\Seatbelt_Detection\weights\best.pt')
metrics = model.val(data=r'C:\Umesh college\Project file\Seatbelt_Detection\data.yaml')
print(metrics)
# Out:
# Ultralytics 8.3.85  Python-3.10.6 torch-2.6.0+cpu CPU (12th Gen Intel Core(TM) i5-12450H)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning C:\Umesh college\Project file\Seatbelt_Detection\valid\labels... 14 images, 0 backgrounds, 0 corrupt: 100%|██████████| 14/14 [00:00<00:00, 130.29it/s]
# val: New cache created: C:\Umesh college\Project file\Seatbelt_Detection\valid\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:07<00:00,  7.89s/it]
#                    all         14         28      0.755      0.679       0.77      0.382
#            no seatbelt          5          7      0.742      0.571      0.758      0.365
#               seatbelt         12         21      0.768      0.787      0.782      0.398
# Speed: 2.9ms preprocess, 547.7ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs\detect\val2
# ...
